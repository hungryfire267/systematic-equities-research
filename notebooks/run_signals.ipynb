# %%
import sys
from pathlib import Path

ROOT = Path(r"C:\Users\Gordon Li\Desktop\systematic_project")
sys.path.insert(0, str(ROOT))

# verify it's actually first
print("sys.path[0] =", sys.path[0])
# Out:
# sys.path[0] = C:\Users\Gordon Li\Desktop\systematic_project

# %%
import sys
from pathlib import Path

ROOT = Path(r"C:\Users\Gordon Li\Desktop\systematic_project")
sys.path.insert(0, str(ROOT))

# optional sanity checks
print("sys.path[0]:", sys.path[0])
# Out:
# sys.path[0]: C:\Users\Gordon Li\Desktop\systematic_project

# %%
from scripts.signals import Kalman
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 from scripts.signals import Kalman
#
# ModuleNotFoundError: No module named 'scripts.signals'

# %%
from scripts.signals import Kalman

kalman_pipeline = Kalman()
kalman_pipeline.plot_kalman_comparison(["CBA.AX", "ZIP.AX"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 from scripts.signals import Kalman
#       3 kalman_pipeline = Kalman()
#       4 kalman_pipeline.plot_kalman_comparison(["CBA.AX", "ZIP.AX"])
#
# ModuleNotFoundError: No module named 'scripts.signals'

# %%
import yfinance as yf
import pandas as pd

# %%
ticker = yf.Ticker("CSL.AX")

# 1) Daily adjusted close over 4 years
prices = ticker.history(period="4y", auto_adjust=True)[["Close"]].copy()
prices.index = pd.to_datetime(prices.index).tz_localize(None)

# 2) Quarterly balance sheet (preferred for smoother P/B series)
# If quarterly is empty, fall back to annual balance sheet
bs = ticker.quarterly_balance_sheet.copy()
bs
# Out:
#                                                       2024-12-31
# Ordinary Shares Number                              4.842067e+08
# Share Issued                                        4.842067e+08
# Net Debt                                            1.044000e+10
# Total Debt                                          1.196400e+10
# Tangible Book Value                                 2.277000e+09
# Invested Capital                                    3.052300e+10
# Working Capital                                     5.234000e+09
# Net Tangible Assets                                 2.277000e+09
# Common Stock Equity                                 1.855900e+10
# Total Capitalization                                2.788500e+10
# Total Equity Gross Minority Interest                2.054600e+10
# Minority Interest                                   1.987000e+09
# Stockholders Equity                                 1.855900e+10
# Gains Losses Not Affecting Retained Earnings        6.520000e+08
# Other Equity Adjustments                            6.520000e+08
# Retained Earnings                                   1.733100e+10
# Capital Stock                                       5.760000e+08
# Common Stock                                        5.760000e+08
# Total Liabilities Net Minority Interest             1.790100e+10
# Total Non Current Liabilities Net Minority Inte...  1.182700e+10
# Other Non Current Liabilities                       5.280000e+08
# Employee Benefits                                   2.980000e+08
# Non Current Pension And Other Postretirement Be...  2.980000e+08
# Non Current Deferred Liabilities                    1.520000e+09
# Non Current Deferred Taxes Liabilities              1.520000e+09
# Long Term Debt And Capital Lease Obligation         9.326000e+09
# Long Term Debt                                      9.326000e+09
# Long Term Provisions                                1.550000e+08
# Current Liabilities                                 6.074000e+09
# Current Deferred Liabilities                        2.050000e+08
# Current Deferred Taxes Liabilities                  2.050000e+08
# Current Debt And Capital Lease Obligation           2.638000e+09
# Current Debt                                        2.638000e+09
# Other Current Borrowings                            2.638000e+09
# Current Provisions                                  2.540000e+08
# Payables And Accrued Expenses                       2.977000e+09
# Payables                                            2.977000e+09
# Accounts Payable                                    2.977000e+09
# Total Assets                                        3.844700e+10
# Total Non Current Assets                            2.713900e+10
# Other Non Current Assets                            1.650000e+08
# Defined Pension Benefit                             4.500000e+07
# Non Current Deferred Assets                         8.680000e+08
# Non Current Deferred Taxes Assets                   8.680000e+08
# Investments And Advances                            1.780000e+08
# Other Investments                                   1.780000e+08
# Goodwill And Other Intangible Assets                1.628200e+10
# Other Intangible Assets                             1.628200e+10
# Net PPE                                             9.601000e+09
# Gross PPE                                           9.601000e+09
# Machinery Furniture Equipment                       9.601000e+09
# Current Assets                                      1.130800e+10
# Current Deferred Assets                             3.900000e+07
# Current Deferred Taxes Assets                       3.900000e+07
# Inventory                                           6.139000e+09
# Receivables                                         3.606000e+09
# Accounts Receivable                                 3.606000e+09
# Cash Cash Equivalents And Short Term Investments    1.524000e+09
# Cash And Cash Equivalents                           1.524000e+09
# Cash Financial                                      1.524000e+09

# %%
bs_q = ticker.quarterly_balance_sheet.copy()
bs_a = ticker.balance_sheet.copy()

bs = bs_q if not bs_q.empty and bs_q.shape[1] >= 4 else bs_a

# %%
bs
# Out:
#                                                     2025-06-30    2024-06-30  \
# Ordinary Shares Number                            4.842121e+08  4.832527e+08
# Share Issued                                      4.842121e+08  4.832527e+08
# Net Debt                                          7.679000e+09  8.862000e+09
# Total Debt                                        1.149800e+10  1.218300e+10
# Tangible Book Value                               3.150000e+09  1.017000e+09
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  2.157000e+09  1.657000e+09
# Other Short Term Investments                               NaN           NaN
# Cash And Cash Equivalents                         2.157000e+09  1.657000e+09
# Cash Equivalents                                  9.630000e+08  7.720000e+08
# Cash Financial                                    1.194000e+09  8.850000e+08
#
#                                                     2023-06-30    2022-06-30  \
# Ordinary Shares Number                            4.823693e+08  4.817063e+08
# Share Issued                                      4.823693e+08  4.817063e+08
# Net Debt                                          8.980000e+09           NaN
# Total Debt                                        1.222700e+10  9.657800e+09
# Tangible Book Value                              -6.600000e+08  1.193940e+10
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  1.548000e+09  1.043640e+10
# Other Short Term Investments                               NaN           NaN
# Cash And Cash Equivalents                         1.548000e+09  1.043640e+10
# Cash Equivalents                                  5.520000e+08  8.905400e+09
# Cash Financial                                    9.960000e+08  1.531000e+09
#
#                                                     2021-06-30
# Ordinary Shares Number                                     NaN
# Share Issued                                               NaN
# Net Debt                                          2.815700e+09
# Total Debt                                                 NaN
# Tangible Book Value                                        NaN
# ...                                                        ...
# Cash Cash Equivalents And Short Term Investments           NaN
# Other Short Term Investments                      4.800000e+06
# Cash And Cash Equivalents                                  NaN
# Cash Equivalents                                           NaN
# Cash Financial                                             NaN
#
# [85 rows x 5 columns]
